# %% [markdown]
# # OLLA Pseudo-code
#
# Here is the way I want to structure OLLA.

# %%
# Import obligatory packages.

import numpy as np
import matplotlib.pyplot as plt 
import xarray as xr
import glob

from getStats import getStats
from getForcingFunctions import getForcingNetCDF
from getOLLA import getOLLA

# %%
# Import files into current terminal.

PATH="/data/keeling/a/adammb4/SGP_proj_2021/DATA/"
precip_data=glob.glob(PATH+"SGP_precip*")
rad_data = glob.glob(PATH+"SGP_Best*")

#hum_data = glob.glob(PATH+"entirely different.nc")
#temp_data = glob.glob(PATH+"sheik.nc")

#ds1 = xr.open_dataset(rad_data[0])
#ds2 = xr.open_dataset(precip_data[0])

#rad = ds1["BestEstimate_down_short_hemisp"].values
#prec = ds2["precip"].values

#fig, ax = plt.subplots(1, figsize=(14,10))

#ax.plot(rad)
#ax.set_ylim((-100,100))

# %%
# Send files to statistics program to generate relevant statistical quantities.

# Data variable names are "precip" and "BestEstimate_down_short_hemisp" for precipitation and radiation, respectively.
# This has been updated IN getStats.py. 

threshold = 0

stats_array = getStats(rad_data, precip_data, threshold)

stats_array
# Out:
# 5
# 132480
# 132480
# 131040
# 132480
# 132480
# array([3.46315521e+02, 1.29007507e+03, 4.18045471e+02, 4.84291086e-05,
#        1.74090033e-03, 3.19336466e-02, 2.79184049e-01])

# %%
# Pass resulting statistical quantities to a program that returns a red forcing .nc that is calibrated to said 
# statistical quantities; also pass the filename for ease of reference in next step

tot_years = 2
filename = "SGP_synth_20sum"

getForcingNetCDF(tot_years, stats_array, PATH+filename+".nc")

# THIS IS SAVED TO PATH ABOVE NOT TO LOCAL DIRECTORY
# Out:
# [4.637633077588798e-06, 1.1055880289564948, 0.0015790521290261143, 1.6760876495212786, 0.7364587726006991, 0.00042285818184167363, 0.01806823003184258, 9.997948941558647e-06, 0.4993424945989175, 0.0005026513483907244, 1.2315978362474493, 0.003959213912101967, 0.005314029273985948, 0.028984691543125562, 0.0021714526317973297, 0.7774839496217505, 0.0013504032329703347, 0.008732282563691964, 0.14897367787227622, 0.004070573946619016, 0.06998662934779876, 0.0038799164882370347, 0.00018960321983154196, 0.006932574985616502, 0.007910347455234393, 1.0733073232365491e-05, 0.23801307020509554, 0.0016978415204352058, 0.0008212345845249067, 0.0032028060558705563, 3.521185708589827e-05, 0.2149460093754235, 0.03962194411449238, 0.24670779839244067, 0.16747435337586808, 0.4490467789228227, 0.6823073774842915, 0.005365439708187376, 0.42974131635961166, 0.04638401004395973, 0.16187632991736492, 0.0011354255909488116, 0.008473485247401736, 0.0026354084345093123, 0.012361683393843005, 4.7194198071411095e-05, 0.626302062329985, 0.012215363519290472, 0.32214450380974924, 9.061999172184373e-06, 2.413646237454305e-06, 2.1380590758641334, 0.04604334508521873, 0.22365628858445707, 0.14948174543476936, 9.216276028446649e-05, 0.06807641866045401, 0.4571525549383977, 0.028157058294118003, 0.1781235036002645, 0.002854959513076413, 0.01432378326061302, 0.538224594220272, 1.2453223799880688, 0.09355179822851355, 0.059077350878027256, 1.1645219884932938, 0.006434316111395858, 0.005169338221103134, 0.005200129572232741, 0.3620552709286238, 0.35262257159329474, 0.001915142508883358, 0.3620765501421553, 0.050214249850395604, 0.0045609954666633945, 0.4440802988458865, 0.18522761050462289, 1.1512796275022694, 0.1883776970841405, 0.1626912386568877, 1.303958742962702, 1.2995937503822839, 0.08975885386117832, 0.17208578218322898, 0.0878126973701533, 0.001049489240895008, 0.3502804519255646, 0.0016814935954210142, 2.5015832416794837e-08, 0.0757021185537537, 0.07701998172115486, 1.6236967434926441, 0.13687839326596415, 1.2124032210158746]

# %%
# Import .nc as forcing

forcing = glob.glob(PATH+filename+".nc")

#ds = xr.open_dataset(forcing[0])
#forcing4 = ds["F_solar"].values
#plt.plot(forcing4[:,0])
#plt.xlim(0,1440*2)

# %%
# Send forcing information to OLLA

# Might need for loop situation here, but basic idea is 

temp_array, mois_array = getOLLA(forcing)

# %%
# Print & plot the results from OLLA

# Generic plotting business

fig, ax = plt.subplots(2, figsize=(14,10))

ax[0].plot(temp_array[:,0])
ax[0].set_ylim((10, 370))
ax[0].set_ylabel(r"Atmospheric Temperature (K)")
ax[0].set_xlabel(r"Minute")

ax[1].plot(mois_array[:,0])
ax[1].set_ylabel(r"Moisture content")
ax[1].set_xlabel(r"Minute")
#ax[1].set_ylim((0,10**(-4)))
"""
ax[1].plot(temp_array[:,1])

ax[2].plot(temp_array[:,2])

ax[3].plot(temp_array[:,3])

ax[4].plot(temp_array[:,4])
"""
# Out:
# '\nax[1].plot(temp_array[:,1])\n\nax[2].plot(temp_array[:,2])\n\nax[3].plot(temp_array[:,3])\n\nax[4].plot(temp_array[:,4])\n'
