# %% [markdown]
# # OLLA Code
#
# The One Layer Land Atmosphere Code. :)

# %%
# Import obligatory packages.

import numpy as np
import matplotlib.pyplot as plt 
import xarray as xr
import glob
import random

from getStats import getStats, getRemoveDefects
from getForcingFunctions import getForcingNetCDF
from getOLLA import getOLLASyn, getOLLAObs

# %%
# Import files into current terminal.

PATH="/data/keeling/a/adammb4/SGP_proj_2021/DATA/"
precip_data=glob.glob(PATH+"SGP_precip*")
rad_data = glob.glob(PATH+"SGP_Best*")

precip_data_var = "precip"
rad_data_var = "BestEstimate_down_short_hemisp"

# %%
# Send files to statistics program to generate relevant statistical quantities.

# Data variable names are "precip" and "BestEstimate_down_short_hemisp" for precipitation and radiation, respectively.
# This has been updated IN getStats.py. 

threshold = 0

stats_array = getStats(rad_data, rad_data_var, precip_data, precip_data_var, threshold)

stats_array
# Out:
# array([3.13691621e+02, 1.07923185e+03, 9.08223299e+02, 1.40227337e+02,
#        3.75419935e-01, 3.16600000e+03, 2.81900001e+00])

# %%
## Pass resulting statistical quantities to a program that returns a red forcing .nc that is calibrated to said 
# statistical quantities; also pass the filename for ease of reference in next step

tot_years = 2
filename = "SGP_synth_20sum"

getForcingNetCDF(tot_years, stats_array, PATH+filename+".nc")

# THIS IS SAVED TO PATH ABOVE NOT TO LOCAL DIRECTORY

# %%
# Import .nc as forcing

synforcing = glob.glob(PATH+filename+".nc")

#fig, ax = plt.subplots(1, figsize=(14,7))
#ds = xr.open_dataset(forcing[0])
#forcing4 = ds["precip_syn"].values
#ax.plot(forcing4[:,0])
#ax.set_xlim(20000,40000)

# %%
# Send forcing information to OLLA

# Might need for loop situation here, but basic idea is 

sumnum = 3 # which summer for observational data

syn_temp_array, syn_mois_array = getOLLASyn(synforcing)
obs_temp_array, obs_mois_array = getOLLAObs(rad_data, precip_data, sumnum)

# %%
# Print & plot the results from OLLA

# Generic plotting business

fig, ax = plt.subplots(2,2, figsize=(20,10))

ax[0,0].plot(syn_temp_array[:,0])
ax[0,0].set_ylim((0, 370))
ax[0,0].set_ylabel(r"Atmospheric Temperature (K)")
ax[0,0].set_xlabel(r"Minute")
ax[0,0].set_title("Forced with Synthetic Data")

ax[1,0].plot(syn_mois_array[:,0])
ax[1,0].set_ylabel(r"Moisture content")
ax[1,0].set_xlabel(r"Minute")
#ax[1,0].set_ylim((0,10**(-4)))

ax[0,1].plot(obs_temp_array)
ax[0,1].set_ylim((0, 370))
ax[0,1].set_ylabel(r"Atmospheric Temperature (K)")
ax[0,1].set_xlabel(r"Minute")
ax[0,1].set_title("Forced with Observations")

ax[1,1].plot(obs_mois_array)
ax[1,1].set_ylabel(r"Moisture content")
ax[1,1].set_xlabel(r"Minute")
#ax[1,1].set_ylim((0,10**(-4)))
# Out:
# Text(0.5, 0, 'Minute')

# %% [markdown]
# # Comparative Figures for Observations against Simulations
#
# We compute some quantities to help us get a better idea of how the forcing and model results are related.

# %%
ds1 = xr.open_dataset(rad_data[sumnum])
ds2 = xr.open_dataset(precip_data[sumnum])
ds3 = xr.open_dataset(synforcing[0])

obs_solar = ds1[rad_data_var].values
F_solar_fixed = getRemoveDefects(obs_solar,"BestEstimate_down_short_hemisp")
F_solar_clean = np.convolve(F_solar_fixed, np.ones(60)/60, mode='same') # smooth data on hour window

obs_precip = getRemoveDefects(ds2[precip_data_var].values, "precip")

syn_solar = ds3["F_solar"].values
syn_precip = ds3["precip_syn"].values

syn_precip.shape
# Out:
# (132480, 2)

# %%
obs_cf = 1 - F_solar_clean * (max(F_solar_clean))**(-1)
syn_cf = 1 - syn_solar[:,0] * (max(syn_solar[:,0]))**(-1)

for i in range(0,len(obs_cf)):
    if obs_cf[i] > 1:
        obs_cf[i] = 1
        
    if obs_cf[i] < 0:
        obs_cf[i] = 0
        
for i in range(0,len(syn_cf)):
    if syn_cf[i] > 1:
        syn_cf[i] = 1
        
    if syn_cf[i] < 0:
        syn_cf[i] = 0

# %%
# make cumulative arrays 

tot_syn_precip = []
tot_obs_precip = []
tmp_s = 0
tmp_o = 0

for i in range(0, syn_precip.shape[0]):
    tmp_s += syn_precip[i,0]
    tot_syn_precip.append(tmp_s)
    
for i in range(0, len(obs_precip)):
    tmp_o += obs_precip[i]
    tot_obs_precip.append(tmp_o)

# %%
fig, ax = plt.subplots(5,2, figsize=(20,30))

ax[0,0].plot(syn_solar[:,0])
#ax[0,0].set_ylim((0, 370))
ax[0,0].set_ylabel(r"Solar Radiation W $m^{-2}$")
ax[0,0].set_xlabel(r"Minute")
ax[0,0].set_title("Synthetic Information")

ax[1,0].plot(tot_syn_precip)
ax[1,0].set_ylabel(r"Precipiatation Amount (cm?)")
ax[1,0].set_xlabel(r"Minute")
#ax[1,0].set_ylim((0,10**(-4)))

ax[2,0].plot(syn_cf)
ax[2,0].set_ylabel(r"Cloud Fraction")

ax[3,0].plot(syn_temp_array[:,0])
#ax[2,0].set_ylim((0, 370))
ax[3,0].set_ylabel(r"Atmospheric Temperature (K)")
ax[3,0].set_xlabel(r"Minute")

ax[4,0].plot(syn_mois_array[:,0])
ax[4,0].set_ylabel(r"Moisture content")
ax[4,0].set_xlabel(r"Minute")
#ax[3,0].set_ylim((0,10**(-4)))

ax[0,1].plot(F_solar_clean)
#ax[0,1].set_ylim((0, 370))
ax[0,1].set_ylabel(r"Solar Radiation W $m^{-2}$")
ax[0,1].set_xlabel(r"Minute")
ax[0,1].set_title("Observational Information")

ax[1,1].plot(tot_obs_precip)
ax[1,1].set_ylabel(r"Precipiatation Amount (cm?)")
ax[1,1].set_xlabel(r"Minute")
#ax[1,1].set_ylim((0,10**(-4)))

ax[2,1].plot(obs_cf)
ax[2,1].set_ylabel(r"Cloud Fraction")

ax[3,1].plot(obs_temp_array)
#ax[2,1].set_ylim((0, 370))
ax[3,1].set_ylabel(r"Atmospheric Temperature (K)")
ax[3,1].set_xlabel(r"Minute")
ax[3,1].set_title("Forced with Observations")

ax[4,1].plot(obs_mois_array)
ax[4,1].set_ylabel(r"Moisture content")
ax[4,1].set_xlabel(r"Minute")
#ax[1,3].set_ylim((0,10**(-4)))
# Out:
# Text(0.5, 0, 'Minute')
